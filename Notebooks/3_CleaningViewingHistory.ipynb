# %% [markdown]
# # Packages importation

# %%
import pandas as pd
import numpy as np
import glob
import re
from collections import Counter
from loky import ProcessPoolExecutor

# %% [markdown]
# # Functions definition

# %% [markdown]
# The **clean_content** function allows you to clean up a history. For example if an user has watched a series, and therefore several episodes, we will have a line for each episode. But we want to keep only the name of the series, and this name in one go.
#
# The **clean_viewing_history** function is used to clean up all the history we have at our disposal.
#
# The **all_history** function is used to parallelize the function above.

# %%
def clean_content(hist):
    liste = []
    already = []

    for elem in hist:
        inter = elem.split(':')
        if len(inter)>2:
            if re.search(r"(.*): Saison [0-9]{1,}:", elem):
                liste.append(re.findall(r"(.*): Saison [0-9]{1,}:", elem)[0])
                already.append(elem)
            elif re.search(r"(.*): Partie [0-9I]{1,}:", elem):
                liste.append(re.findall(r"(.*): Partie [0-9I]{1,}:", elem)[0])
                already.append(elem)
            elif re.search(r"(.*): Collection:", elem):
                liste.append(re.findall(r"(.*): Collection:", elem)[0])
                already.append(elem)
            else:
                liste.append(inter[0])
                already.append(elem)
        elif len(inter)!=2:
            liste.append(elem)
            already.append(elem)

    not_yet = [i for i in hist if i not in already]
    already_not_yet = Counter([i.split(':')[0] for i in not_yet]).most_common()
    already_not_yet = [i[0] for i in already_not_yet if i[1]>5]

    for elem in not_yet:
        if len(elem.split(' : '))==2:
            liste.append(elem)
        elif elem.split(':')[0] not in already_not_yet:
            liste.append(elem)

    return np.unique(liste)

def clean_viewing_history(filename):
    historique = pd.read_csv(filename, sep = ',').Title
    historique = [elem.replace('\xa0', ' ').replace('*', '\*') for elem in historique if 'Bande-annonce' not in elem]
    historique = [elem for elem in historique if 'Bientôt disponible' not in elem]
    historique = clean_content(historique)
    return historique

def all_history(key):
    with ProcessPoolExecutor() as epool:
        mapped_values = epool.map(clean_viewing_history, key)
    return list(mapped_values)

# %% [markdown]
# # Cleaning viewing history

# %%
files = sorted(glob.glob('../Data/Historiques_FilmsVu_Netflix/Historique_user*.csv'))
files
# Out:
# ['../Data/Historiques_FilmsVu_Netflix\\Historique_user1.csv',
#  '../Data/Historiques_FilmsVu_Netflix\\Historique_user2.csv',
#  '../Data/Historiques_FilmsVu_Netflix\\Historique_user3.csv',
#  '../Data/Historiques_FilmsVu_Netflix\\Historique_user4.csv']

# %%
clean_viewing_history(files[0])[:10]
# Out:
# array(['6 Underground', 'After Life', 'Ahmed Sylla - Avec un grand A',
#        'American Psycho', 'American Vandal',
#        'Ano Hi Mita Hana no Namae o Bokutachi wa Mada Shiranai', 'Archer',
#        "Atlantide : L'empire perdu", 'Atypical', 'Avatar '], dtype='<U77')

# %%
hist = all_history(files)
hist
# Out:
# [array(['6 Underground', 'After Life', 'Ahmed Sylla - Avec un grand A',
#         'American Psycho', 'American Vandal',
#         'Ano Hi Mita Hana no Namae o Bokutachi wa Mada Shiranai', 'Archer',
#         "Atlantide : L'empire perdu", 'Atypical', 'Avatar ',
#         'B: The Beginning', 'BTOOOM!',
#         "Bill Burr: I'm Sorry You Feel That Way", 'Bill Burr: Paper Tiger',
#         'Bill Burr: Walk Your Way Out', 'Black Bullet', 'Black Butler',
#         'Black Butler : Book of the Atlantic', 'Black Mirror',
#         'Black Mirror: Bandersnatch',
#         'Blanche Gardin : Je parle toute seule', 'Blue Exorcist',
#         'Brooklyn Nine-Nine', 'Charlotte', 'Cowboy Bebop',
#         'DanMachi : Familia Myth', 'Dave Chappelle',
#         'Dave Chappelle: Equanimity & The Bird Revelation',
#         'Dave Chappelle: Sticks & Stones', 'Daybreak',
#         'Death Parade: Death Parade', 'Devilman Crybaby', 'Dix pour cent',
#         'Désenchantée', 'En bref', 'Entre deux fougères : Le film',
#         'Erased', 'Everything Sucks!', 'Family Guy',
#         'Fary Is the New Black', 'Final Space',
#         'Flavors of Youth: International Version', 'Fullmetal Alchemist',
#         'Fullmetal Alchemist: Brotherhood', 'Gad Elmaleh: American Dream',
#         'Gambling school', 'Game Over, Man!', 'High Score Girl',
#         'James Acaster: Repertoire', 'Katanagatari',
#         'Kingsman : Services secrets', 'Klaus', "L'Auberge espagnole",
#         'La Grande Classe', 'La ballade de Buster Scruggs',
#         'Le Dernier pub avant la fin du monde',
#         'Le Monde incroyable de Gumball', 'Le Nouveau stagiaire',
#         'Le Piano dans la forêt', 'Legend', 'Les têtes vides',
#         'Louis C.K. 2017', 'Lovesick', 'Lucifer',
#         "Lupin III : L'aventure italienne", 'MINDHUNTER', 'Manhunt',
#         'March Comes in Like a Lion', 'Misfits', 'Mr. Nobody',
#         'One-Punch Man', 'Paradise Police', 'Peaky Blinders',
#         'Popstar: Célèbre à tout prix', 'Prison Break', 'Rick et Morty',
#         'Ricky Gervais: Humanity', 'STEINS;GATE', 'Saiki Kusuo no Ψ Nan',
#         'Samouraï Champloo', 'Sausage Party : La Vie privée des aliments',
#         'Sense8', 'Sex Education', 'Sherlock', 'Sherlock Holmes',
#         'Sirius the Jaeger', 'Snatch', 'South Park', 'South Park, le film',
#         'Steins;Gate : Fuka Ryouiki no Déjà vu',
#         'Sword Oratoria: Is It Wrong to Try to Pick Up Girls in a Dungeon? On the Side',
#         'Terror in Resonance',
#         'The Amazing World of Gumball: Season 1_hook_primary_16x9',
#         'The Big Short', 'The Lobster', 'The Nice Guys',
#         'The Seven Deadly Sins', 'The Tatami Galaxy', 'Umbrella Academy',
#         'War Dogs', 'Watchmen : les gardiens', 'Your lie in April'],
#        dtype='<U77'), array(['127 Heures', '13 Novembre ', '13 Reasons Why',
#         '13 Reasons Why : Au-delà des raisons', '17 filles', '1922',
#         '2012', '21 Jump Street', '22 Jump Street',
#         '28 semaines plus tard', '3 %', "300 : La naissance d'un empire",
#         '40 ans, toujours puceau', '5 ans de réflexion', '7 Psychopathes',
#         '72 animaux dangereux en Amérique latine', 'A Christmas Prince',
#         'A Christmas Prince: The Royal Baby',
#         'A Christmas Prince: The Royal Wedding', 'A.X.L.', 'Ad Vitam',
#         'Adventure Time', 'Afrique sauvage', 'Age of Youth',
#         'Agents Presque Secrets', 'Ahmed Sylla - Avec un grand A',
#         'Alex Strangelove', 'Allo maman ici bébé', 'Altered Carbon',
#         'Always Be My Maybe', 'American Experience: Tesla',
#         'American Factory : Conversation avec les Obama',
#         'American Factory : Un milliardaire chinois en Ohio',
#         'American Horror Story', 'American Nightmare',
#         'American Nightmare 2: Anarchy', 'American Pie - Campus en folie',
#         'American Pie : String Academy', 'American Psycho',
#         'American Vandal', 'Annihilation', 'Anon', 'Apocalypse ',
#         'Appelez-moi DJ Rebel', 'Archer', 'Arrow', 'Ash vs. Evil Dead',
#         'Atypical', 'Audrie et Daisy',
#         'Auschwitz, les Nazis et la solution finale', 'Aux yeux de tous',
#         'Avatar ', "Avengers : L'ère d'Ultron",
#         "Avengers : L'équipe des super héros", 'Avicii: True Stories',
#         'Baby', 'Baby Boss : les affaires reprennent', 'Barbecue',
#         'Barons de la drogue', 'Bates Motel', 'Better Call Saul',
#         'Beyond Stranger Things', 'Bienvenue chez Mamilia',
#         'Bienvenue à Marly Gomont', 'Bienvenue à Zombieland', 'Big Mouth',
#         'Billy Elliot', 'Bird Box', 'Bitten', 'Black Lightning',
#         'Black Mirror', 'Black Mirror: Bandersnatch',
#         'Blanche Gardin : Je parle toute seule', 'Bleach',
#         'BoJack Horseman', "Bob l'éponge", 'Bodyguard', 'Brain on Fire',
#         'Breaking Bad', 'Brooklyn Nine-Nine', 'Burn After Reading',
#         "Bébé mode d'emploi", 'Cam', 'Camping', 'Camping 2', 'Camping car',
#         'Candy Jar', 'Cap sur le Congrès', 'Capitaine Phillips', 'Captive',
#         'Casino', 'Cauchemars et canulars',
#         'Ce qui vous attend si vous attendez un enfant', 'Cercle',
#         'Chair de Poule - le film', 'Charlie et la chocolaterie',
#         'Chelsea Peretti: One of the Greats', 'Chucky la poupée de sang',
#         'Cinquante Nuances de Grey', 'Cloud Atlas', 'Cloverfield',
#         'Collateral', 'College Attitude', 'Colombiana',
#         'Comme Cendrillon : Un vœu pour Noël', 'Comment savoir',
#         "Comment trouver l'amour à la Saint-Valentin ?",
#         'Conjuring: Les dossiers Warren', 'Contracted', 'Coraline',
#         'Countdown to Death: Pablo Escobar', 'Coup de foudre à Manhattan',
#         'Coup de foudre à Notting Hill', 'Crazy Amy', 'Crazy Dad',
#         'Crazy, Stupid, Love', "Célibataire, mode d'emploi",
#         "DC's Legends of Tomorrow", 'DEATH NOTE', 'DUFF : le faire-valoir',
#         'Da Vinci Code', 'Dallas Buyers Club', 'Dance Academy : Le Retour',
#         'Dark', 'Dead Snow', 'Dear White People', 'Death Note',
#         'Dernier train pour Busan', 'Des étoiles plein les yeux',
#         'Designated Survivor', 'Destination Finale 5', 'Didier',
#         'Dirk Gently, détective holistique', 'Dirty Dancing', 'Dirty John',
#         'Disco', 'Diversion', 'Dix pour cent', 'Django Unchained',
#         'Docteur Patch', 'Doctor Who', 'Downton Abbey', 'Dr Foster',
#         'Dracula', 'Dragons', "Dumplin'", 'Duo à trois', 'Dynastie',
#         'Délire express', 'Dépression et des potes', 'Désenchantée',
#         'Einsatzgruppen, les commandos de la mort',
#         'El Camino : Un film Breaking Bad', 'Elementary',
#         'Elisa et Marcela', 'Elle est trop bien', 'Ellen DeGeneres',
#         "En cloque, mode d'emploi", 'En route !', 'Enquêtes codées',
#         'Equalizer', 'Eternal Sunshine of the Spotless Mind', 'Extinction',
#         'Extremely Wicked, Shockingly Evil and Vile', 'Fahrenheit 9/11',
#         'Falling Inn Love', 'Famille recomposée', 'Family Business',
#         'Fargo', 'Fary Is the New Black', 'Fievel et le Nouveau Monde',
#         'Flash', "Flocons d'amour", 'Footloose', 'Foresti Party',
#         'Forrest Gump', 'Frangins malgré eux', 'Fresh Meat', 'Friends',
#         'Friends with Money', 'GLOW', 'Gad Elmaleh : La vie normale',
#         'Gad Elmaleh : Sans Tambour', 'Gad Elmaleh: American Dream',
#         "Gad Elmaleh: L'Autre C'Est Moi", 'Gang de Requins',
#         'Gilmore Girls', 'Girlboss', 'Girls Only', 'Glee', 'Glitter Force',
#         'Godless', 'Gone Baby Gone', 'Gone Girl', 'Good Girls',
#         'Gossip Girl', 'Grease', 'Grégory', 'Gypsy', 'H2O',
#         'HUMORISTES du monde', 'Hancock',
#         'Happiness Therapy (Silver Linings Playbook)', 'Happy New Year',
#         "Harry Potter et l'Ordre du phénix",
#         'Harry Potter et la Coupe de feu',
#         'Harry Potter et le Prince de sang-mêlé',
#         'Harry Potter et les Reliques de la mort : 1ère partie',
#         "Harry Potter à l'école des sorciers", 'Heartbeats', 'Her',
#         'Histoires sensuelles', 'Hitch - Expert en séduction',
#         'Hitler, une carrière', 'Hitman', 'Home for Christmas', 'Hot Fuzz',
#         'House of Cards', 'How I Met Your Mother', 'How It Ends', 'Hulk',
#         'I AM A KILLER', 'I Am Mother', 'I Feel Pretty', 'I Love You, Man',
#         "I'm in Love with a Church Girl", 'Il était temps', 'Imperium',
#         'In the air', 'In-Lawfully Yours', 'Inception',
#         'Inglourious Basterds', 'Insatiable', 'Interstellar',
#         'Into the Forest', 'Ip Man 3', "Isn't It Romantic", 'Jackie Brown',
#         'Jacky au royaume des filles', 'Jane the Virgin',
#         'Je ne suis pas un homme facile', "Je préfère qu'on reste amis",
#         'Jessie', 'Johnny English, le retour', 'Julie & Julia',
#         'Jumping the Broom', "Jupiter : le destin de l'univers",
#         'Jurassic Park', 'Just Friends', 'Kate & Leopold', 'Kick-Ass 2',
#         'Kill Bill : volume 1', 'Kill Bill : volume 2',
#         'Kirikou et la sorcière', 'Klaus', 'Kung Fu Panda',
#         'Kung Fu Panda 2', 'Kung Fu Panda 3', "Kuzco, l'empereur mégalo",
#         "L'Agence tous risques", "L'Assaut", "L'Attrape parents",
#         "L'Auberge espagnole", "L'abominable vérité", "L'alchimie de Noël",
#         "L'art du rangement avec Marie Kondo", "L'homme parfait",
#         "L'interview qui tue", "L'oeil du mal", "L'école des célibataires",
#         "L'étrange histoire de Benjamin Button",
#         "L'île des Miam-nimaux : Tempête de boulettes géantes 2",
#         'LOL USA', 'La Cité de la peur', 'La Croisiere', 'La Dame de fer',
#         'La Délicatesse', 'La Folle Journée de Ferris Bueller',
#         'La Fracture', 'La Grande Aventure Lego', 'La Grande Classe',
#         'La Liste de Schindler', 'La Momie', 'La Môme',
#         'La Princesse de Chicago', 'La Terre à plat',
#         'La Vraie vie des profs', 'La ballade de Buster Scruggs',
#         'La casa de papel', 'La défense Lincoln',
#         'La princesse et la grenouille', 'La romance à Manhattan',
#         'La rumeur court...', 'Land Girls', 'Last Night', 'Le Client',
#         "Le Dernier Maître de l'air", 'Le Fils de Saul',
#         'Le Nouveau stagiaire', "Le Noël d'Angela", 'Le Pari',
#         'Le Parrain', 'Le Prince des dragons', 'Le Prince d’Égypte',
#         'Le Prince et moi', 'Le Prix À Payer', 'Le Sourire de Mona Lisa',
#         'Le choc des Titans', 'Le formidable envol  de Motti Wolkenbruch',
#         'Le mariage de mon meilleur ami', 'Le masque de Zorro',
#         'Le mytho - Just go with it', 'Le paquet', 'Le prince de Bel-Air',
#         'Le talentueux Mr. Ripley', 'Le terminal', 'Le témoin amoureux',
#         'League of Legends : Les origines', 'Leila', 'Les 100',
#         "Les 12 travaux d'Astérix", 'Les Bleus',
#         'Les Bleus - Une autre histoire de France, 1996-2016',
#         'Les Boloss', 'Les Chroniques de San Francisco',
#         "Les Clowns tueurs venus d'ailleurs",
#         'Les Demoiselles du téléphone', 'Les Gardiens de la Galaxie',
#         'Les Invincibles', 'Les Légendaires',
#         'Les Miller, une famille en herbe', 'Les Misérables',
#         'Les Rebelles de la forêt', 'Les Simpson, le film',
#         'Les Suffragettes', 'Les Survivants', 'Les aventures de Tintin',
#         'Les bums de plage', 'Les chroniques de Shannara',
#         'Les chroniques de Spiderwick', 'Les cinq légendes',
#         'Les derniers tsars', 'Les enfants de Timpelbach',
#         'Les femmes de ses rêves', 'Les goûts et les couleurs',
#         'Les noces rebelles', 'Les nouvelles aventures de Sabrina',
#         'Les potes', 'Les Évadés', 'Lettres à Juliette',
#         "Life, l'aventure de la vie", 'Limitless', 'Liv & Maddie',
#         'Living with Yourself', 'Loaded: Loaded', 'Lolita malgré moi',
#         'Love Actually', 'Love Happens', 'Love Story', 'Love next door',
#         'Love, Death & Robots', 'Lucifer', 'MINDHUNTER', 'MOVIE',
#         'MR. RIGHT', 'Ma meilleure ennemie',
#         "Macron : les coulisses d'une victoire",
#         "Madagascar 3, bons baisers d'Europe", 'Malgré tout',
#         'Maman, Papa, la voilà', 'Man of Steel', 'Mange, prie, aime',
#         'Maniac', 'Manipulation', 'Mansfield Park',
#         'Mariage sous la neige', 'Marriage Story', 'Mars',
#         "Marvel's Daredevil", "Marvel's Iron Fist",
#         "Marvel's Jessica Jones", "Marvel's Luke Cage",
#         "Marvel's The Defenders", "Marvel's The Punisher", 'Match Point',
#         'Matilda', 'Megamind', 'Men in Black 3', 'Menteur Menteur',
#         "Merlin l'Enchanteur", "Mesrine : l'ennemi public n°1",
#         "Millénium 3 - La Reine dans le palais des courants d'air",
#         "Millénium, le film - Les hommes qui n'aimaient pas les femmes",
#         'Mince alors !', 'Minecraft : Mode histoire', 'Mirage',
#         'Miss India America', 'Mission: Impossible III', 'Modern Family',
#         'Moi, moche et méchant', 'Monstres contre Aliens',
#         'Monty Python : Sacré Graal !', "Monty Python's Flying Circus",
#         'Morning Glory', 'Mothers and Daughters',
#         'Mowgli : la légende de la jungle', 'Mr. Nobody', 'Mudbound',
#         'Murder', 'Murder Mystery', 'NOVA: Why Sharks Attack', 'Narcos',
#         'Narcos: Mexico', "Ne t'endors pas", 'New Girl', 'Night Run',
#         'Nights in Rodanthe', 'Ninja Assassin',
#         "No Country for Old Men - Non, ce pays n'est pas pour le vieil homme",
#         'No Pain No Gain', 'Nos pires voisins 2', 'Nos voisins les hommes',
#         'Nos âmes la nuit', 'Nos étoiles contraires', 'Nous York',
#         'Now More Than Ever: The History of Chicago', 'Noël à Snow Falls',
#         'Nuits blanches à Seattle', 'OSS 117 Rio ne répond plus', 'Océans',
#         'On My Block', 'Operation Finale', 'Orange Is the New Black',
#         'Orgueil & Préjugés', 'Orphan Black', 'Outlander', 'Pacific Rim',
#         'Paradise Police', 'Pas un bruit', 'Peaky Blinders',
#         'Percy Jackson : le voleur de foudre', "Perdus dans l'espace",
#         'Petits coups montés', 'Pixels', 'Plan Cœur',
#         'Popstar: Célèbre à tout prix', 'Premier jour, dernier jour',
#         'Pretty Little Liars', 'Prison Break', 'Private Life',
#         'Proposition indécente',
#         'Présentateur vedette : la légende de Ron Burgundy',
#         'Pulp Fiction', 'Péché originel', 'Queer Eye',
#         'Queer Eye : Bienvenue au Japon !', "Quelqu'un de bien",
#         'RRRrrrr!!!', 'Raison et sentiments', 'Rango', 'Rebelle',
#         'Red vs. Blue', 'Remember Me', 'Reservoir Dogs', 'Residue',
#         'Rick et Morty', 'Rip Tide', 'Riverdale', 'Rodéo et Juliette',
#         'SHOW', 'SOS sages-femmes', 'SPF-18', 'Sacré Père Noël', 'Safe',
#         'Saint Laurent', 'San Antonio', 'Scary Movie 3',
#         'Seize bougies pour Sam', 'Self Control', 'Sense8',
#         'Sense8 : la création du monde', 'Sept ans au Tibet',
#         'Sex Education', 'Sex Friends', 'Shadowhunters',
#         'Shadowhunters: The Mortal Instruments', 'Shaun of the Dead',
#         'Sherlock', 'Sherlock Holmes', "Sherlock Holmes : Jeu d'ombres",
#         "Shooter, tireur d'élite", 'Shrek', 'Shrek 2',
#         'Shrek 4 : il était une fin', 'Shrek le troisième',
#         'Shutter Island', 'Sick Note', 'Sierra Burgess Is A Loser',
#         'Sinister 2', 'Slumdog Millionaire', 'Snatch',
#         'Snowpiercer, Le Transperceneige', 'South Park',
#         "Souvenirs d'Afrique", 'Spotlight', 'Spy Kids',
#         'Spy kids 3 : Game Over', 'Steve Jobs', 'Stranger Things',
#         "Stretch Armstrong : L'évasion", 'Suicide Squad',
#         'Suits : avocats sur mesure', 'Super blonde', 'Super mamans',
#         'Supernatural', 'Swiped', 'Swiss Army Man', 'TAU', 'Tall Girl',
#         'Taulardes', 'Taylor Swift reputation Stadium Tour', 'Ted 2',
#         'Ted Bundy ', 'Teen Wolf', 'Tel père',
#         'Tempête de boulettes géantes', "That '70s Show",
#         "The Amazing Spider-Man : Le Destin d'un héros", 'The Americans',
#         'The Avengers', 'The Big Bang Theory', 'The Big Lebowski',
#         'The Big Short', 'The Blind Side', 'The Breakfast Club',
#         'The Clapper', 'The Cloverfield Paradox', 'The Crown',
#         'The Dark Knight Rises', 'The Duchess',
#         'The End of the F\\*\\*\\*ing World', 'The Escort', 'The Fall',
#         'The Final Year', 'The Good Place', 'The Good Wife', 'The Holiday',
#         'The Holiday Calendar', 'The IT Crowd', 'The Imitation Game',
#         'The Immigrant', 'The Incredible Jessica James', 'The Innocents',
#         'The Irishman', 'The Kissing Booth', 'The Last Summer',
#         'The Late Bloomer',
#         'The Lonely Island Presents: The Unauthorized Bash Brothers Experience',
#         'The Lucky One', 'The Mask You Live In', 'The Nice Guys',
#         'The Other Woman', 'The Perfect Date', 'The Protector',
#         'The Raid 2', 'The Rain', 'The Royal House of Windsor',
#         'The Silence', 'The Sinner', 'The Social Network', 'The Society',
#         'The Story of Diana', 'The Walking Dead', 'Time Lapse', 'Titans',
#         'To Be a Miss', 'Toi, moi et elle', 'Top Gun',
#         'Total Recall : Mémoires programmées', 'Tout ce qui brille',
#         'Toy Story 3', 'Transformers', 'Transformers 2 : la revanche',
#         'True Grit', 'True Story', 'Trump : Un rêve américain',
#         'Twilight - chapitre 1 : fascination',
#         'Twilight - chapitre 2 : tentation', 'Ultimate Spider-Man',
#         'Umbrella Academy', 'Un Choix', 'Un Havre de Paix - Safe Haven',
#         'Un Homme Idéal', 'Un Noël de folie!', 'Un Noël à croquer',
#         'Un Prince (Presque) Charmant', 'Un Vent De Folie',
#         "Un bonheur n'arrive jamais seul", 'Un heureux événement',
#         "Un homme d'exception", 'Un mariage à organiser',
#         'Un petit souhait pour Noël', 'Un peu, beaucoup, aveuglément',
#         'Un safari pour Noël', 'Un soupçon de magie', 'Unbelievable',
#         'Unbreakable Kimmy Schmidt', 'Under the Dome',
#         'Underworld 3 : Le Soulèvement des Lycans',
#         'Underworld : Nouvelle Ère', 'Une Famille à louer',
#         'Une bouteille à la mer', 'Une femme de tête',
#         'Une seconde chance', 'V pour vendetta', 'Vendredi 13',
#         'Very Bad Cops', 'Very Bad Trip', 'Very Bad Trip 2',
#         'Very Bad Trip 3', 'Vietnam : Un film de Ken Burns et Lynn Novick',
#         'Viral', 'Virgin River', 'Vive les vacances',
#         'Vous avez un message', 'Wakfu',
#         'Wakfu : La quête des six Dofus Eliatropes', 'Wanderlust',
#         'Watchmen : les gardiens', 'We Are Your Friends', 'Welcome Back',
#         'When We First Met', 'Whiplash', 'Wild', 'Wild Australia',
#         'Wild Wild Country', 'Will Hunting', "Workin' Moms", 'World War Z',
#         'Wynonna Earp', 'Yes Man', 'You', 'You vs. Wild', 'Yu-Gi-Oh!',
#         'Zathura : une aventure spatiale', 'Zodiac',
#         'Zoe et Raven : Noël ensemble', 'Zoo', 'À suivre',
#         "À tous les garçons que j'ai aimés", 'Élite'], dtype='<U69'), array(['13 Reasons Why', '6 Underground', 'Ace Ventura en Afrique',
#         'Ace Ventura, détective chiens et chats', 'Adventure Time',
#         'Agents très spéciaux : Code U.N.C.L.E.',
#         'Antoine Griezmann : Champion Du Monde', 'Archer',
#         'Arrested Development', "Avengers : L'ère d'Ultron",
#         'Baby Boss : les affaires reprennent', 'Batman Begins',
#         'Big Mouth', 'Bird Box', 'Birdman', 'Black Mirror',
#         'Black Mirror: Bandersnatch', 'BoJack Horseman',
#         "BoJack Horseman Christmas Special: Sabrina's Christmas Wish",
#         'Bodyguard', 'Breaking Bad', 'Bright', 'Brooklyn Nine-Nine',
#         'College Attitude', 'Comment se faire larguer en 10 leçons',
#         'Dans le cerveau de Bill Gates', 'Daybreak', 'Dead to Me',
#         'Death Note', 'Derren Brown: The Push', 'Dix pour cent',
#         'Désenchantée', 'Easy', 'Edge of Tomorrow',
#         "En taule : mode d'emploi", 'Enemy',
#         'Extremely Wicked, Shockingly Evil and Vile', 'F is for Family',
#         'Falling Inn Love', 'Family Guy', 'Final Space',
#         'Frangins malgré eux', 'Happy!', 'Harry Potter et la Coupe de feu',
#         'Hitman', 'I, Robot', 'Insatiable', 'Interstellar',
#         "Isn't It Romantic", 'Jackass - Le Film', 'La Grande Classe',
#         'La Mort dans la peau', 'La casa de papel', 'La défense Lincoln',
#         'La série des Qui était... ?', 'Le paquet', 'Living with Yourself',
#         'Love, Death & Robots', 'MINDHUNTER', 'Mad Men', 'Maniac',
#         'Marianne', "Marvel's The Punisher", 'Matrix', 'Modern Family',
#         'Mortel', 'Mr. Nobody', 'MythBusters', 'Nos vies après eux',
#         'Obsession secrète', 'Paradise Police', 'Peaky Blinders',
#         'Playboy à saisir', 'Prison Break', 'Prison School',
#         "Quelqu'un de bien", 'Rick et Morty', 'Salt', 'Sense8',
#         'Sept vies', 'Serenity', 'Sex Friends', 'Shaft', 'Shrek',
#         'Snowden', 'South Park', 'Stranger Things', 'Suicide Squad',
#         'Teen Titans Go!', 'The A List', 'The Big Bang Theory',
#         'The Big Lebowski', 'The Blair Witch Project',
#         'The Dark Knight : le chevalier noir', 'The Dark Knight Rises',
#         'The Dictator', 'The End of the F\\*\\*\\*ing World',
#         'The Good Place', 'The Irishman', 'The Nice Guys',
#         'The Open House', 'The Rain', 'The Silence',
#         'The Story of God with Morgan Freeman', 'The Walking Dead',
#         'The Witcher', "The World's Most Extraordinary Homes", 'V Wars',
#         'Velvet Buzzsaw', 'Very Bad Cops', 'Very Bad Dads', 'War Dogs',
#         'Watchmen : les gardiens', 'When We First Met', 'You',
#         'You vs. Wild', 'Zodiac'], dtype='<U59'), array(['Agents très spéciaux : Code U.N.C.L.E.', 'American Horror Story',
#         'Black Mirror', 'Black Mirror: Bandersnatch',
#         'Charlie et la chocolaterie', 'Cinquante Nuances de Grey',
#         'Dracula Untold', 'Jackass - Le Film',
#         'Jackass 3.5 - le film non censuré', 'Johnny English, le retour',
#         'La casa de papel', 'Le Pari', 'Les 100', 'Les rois mages',
#         'Les vacances de Mr. Bean', 'Monster House', 'Orphan Black',
#         'Prison School', 'Rick et Morty', 'Sherlock', 'Stranger Things',
#         'Tall Girl', 'The Walking Dead', 'The Witcher', 'Umbrella Academy'],
#        dtype='<U38')]

# %% [markdown]
# # Exportation

# %%
n = len(hist)
for i in range(n):
    path = f"../Data/Historiques_FilmsVu_Netflix/CleanHistory_user{i+1}.txt"
    content = "\n".join(hist[i])
    with open(path,"w", encoding = "utf-8") as f:
        f.write(content)
