# %%
import networkx as nx
import matplotlib.pyplot as plt
import math

# %%
Graphe_Netflix = nx.read_edgelist("Liaisons films.txt", delimiter = '\t')

# %%
Graphe_Netflix.nodes()
# Out:
# NodeView(('¡Ay, mi madre!', '10 Years', '100 mètres', '15 August', '2 States', '21 Jump Street', '22 Jump Street', '30 ans sinon rien', '30 Days of Luxury', '30 minutes maximum', '48 vœux de Noël', '4L', '4th Man Out', '7 años', 'À Coup Sûr', 'À dix-sept ans', 'A Mission in an Old Movie', 'A Remarkable Tale', "À tous les garçons que j'ai aimés", 'A Very Murray Christmas', 'Abby Sen', 'About Last Night', 'Acapulco La vida va', 'Ace Ventura en Afrique', 'Ace Ventura, détective chiens et chats', 'Action Point', 'Adam Devine: Best Time of Our Lives', 'ADAM SANDLER 100% FRESH', 'Adel Karam: Live from Beirut', "Aditi Mittal: Things They Wouldn't Let Me Say", 'Adorables Ennemies', "Adventureland : Job d'été à éviter", 'Agents Presque Secrets', 'Agents très spéciaux : Code U.N.C.L.E.', 'Ahmed Sylla - Avec un grand A', 'Aile Arasında', 'Aiyya', "Alejandro Sanz : Je suis ce que j'étais", 'Alex Strangelove', 'Algo muy gordo', 'Ali Baba et les 7 nains', 'Ali G', 'Ali Wong: Baby Cobra', 'Ali Wong
# ...

# %%
plt.figure()
nx.draw_networkx(Graphe_Netflix)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65293 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 65293 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22855 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38272 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36929 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
nx.draw(Graphe_Netflix,pos=nx.spring_layout(Graphe_Netflix))
